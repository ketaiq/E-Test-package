# %% [markdown]
# # Dataset Statistics

# %%
import os
import json
from datetime import datetime
import pandas as pd
from statistics import mean
import re

# %% [markdown]
# ## New Bugs From Recent Issues
# - range of created date
# - number per category of inputs
# - number by projects
# - project type

# %%
Defects4AT_PATH = "../Defect4AutonomicTesting/bugs"
Defects4AT_PROJECTS = [
    "spring-boot",
    "shardingsphere",
    "dolphinscheduler",
    "micrometer",
]

# %%
def summarize_stats_of_recent_bugs():
    create_dates = []
    closed_dates = []
    for project in Defects4AT_PROJECTS:
        print(project)
        input_categories = []
        project_path = os.path.join(Defects4AT_PATH, project)
        num_bugs = 0
        for bug_id in os.listdir(project_path):
            bug_path = os.path.join(project_path, bug_id)
            if not str.isnumeric(bug_id) or not os.path.isdir(bug_path):
                continue
            with open(os.path.join(bug_path, "issue.json")) as f:
                bug_metadata = json.load(f)
            create_date = bug_metadata["created_at"]
            closed_date = bug_metadata["closed_at"]
            create_dates.append(datetime.strptime(create_date, "%Y-%m-%dT%H:%M:%SZ"))
            closed_dates.append(datetime.strptime(closed_date, "%Y-%m-%dT%H:%M:%SZ"))
            input_category = bug_metadata["category"]
            input_categories.append(input_category)
            num_bugs += 1
        print("Input Category")
        print(pd.Series(input_categories).value_counts())
        print(f"{num_bugs} bugs in {project}")
        print()

    create_dates.sort()
    closed_dates.sort()
    print(create_dates)
    min_dt = min(create_dates)
    max_dt = max(create_dates)
    print(f"Crate date range: from {min_dt} to {max_dt}")
    print(closed_dates)
    print(f"Closed date range: from {min(closed_dates)} to {max(closed_dates)}")

# %%
summarize_stats_of_recent_bugs()
# Out:
# spring-boot
# Input Category
# new object input             8
# new environment condition    7
# new string input             5
# Name: count, dtype: int64
# 20 bugs in spring-boot
#
# shardingsphere
# Input Category
# new object input    7
# new string input    4
# Name: count, dtype: int64
# 11 bugs in shardingsphere
#
# dolphinscheduler
# Input Category
# new string input             6
# new environment condition    2
# new object input             2
# new number input             1
# Name: count, dtype: int64
# 11 bugs in dolphinscheduler
#
# micrometer
# Input Category
# new environment condition    3
# new object input             3
# new string input             1
# new number input             1
# Name: count, dtype: int64
# 8 bugs in micrometer
#
# [datetime.datetime(2020, 1, 13, 8, 17, 51), datetime.datetime(2020, 3, 2, 8, 10, 39), datetime.datetime(2020, 5, 23, 15, 57), datetime.datetime(2020, 6, 8, 11, 1, 8), datetime.datetime(2020, 7, 16, 8, 37, 1), datetime.datetime(2020, 8, 24, 2, 55, 12), datetime.datetime(2021, 8, 6, 17, 45, 24), datetime.datetime(2021, 9, 7, 12, 7, 26), datetime.datetime(2021, 9, 26, 14, 23, 57), datetime.datetime(2021, 12, 7, 2, 39, 57), datetime.datetime(2022, 3, 4, 15, 11, 1), datetime.datetime(2022, 4, 11, 7, 56, 5), datetime.datetime(2022, 5, 24, 13, 59, 58), datetime.datetime(2022, 5, 29, 16, 48, 5), datetime.datetime(2022, 7, 13, 13, 5, 29), datetime.datetime(2022, 7, 21, 8, 13, 22), datetime.datetime(2022, 8, 3, 7, 27, 44), datetime.datetime(2022, 9, 30, 13, 17, 3), datetime.datetime(2022, 11, 7, 13, 12, 38), datetime.datetime(2023, 2, 15, 18, 15, 12), datetime.datetime(2023, 2, 20, 10, 10, 34), datetime.datetime(2023, 2, 28, 6, 14, 51), datetime.datetime(2023, 3, 16, 9, 55, 26), datetime.datetime(2023, 3, 29, 11, 10, 47), datetime.datetime(2023, 4, 28, 9, 44, 22), datetime.datetime(2023, 5, 5, 10, 45, 30), datetime.datetime(2023, 5, 31, 11, 15, 8), datetime.datetime(2023, 6, 2, 15, 16, 23), datetime.datetime(2023, 6, 13, 20, 42, 25), datetime.datetime(2023, 7, 17, 1, 49, 32), datetime.datetime(2023, 7, 19, 9, 32, 25), datetime.datetime(2023, 7, 28, 2, 14, 27), datetime.datetime(2023, 8, 4, 3, 25, 50), datetime.datetime(2023, 8, 10, 9, 39, 17), datetime.datetime(2023, 9, 5, 10, 54, 52), datetime.datetime(2023, 9, 21, 10, 35), datetime.datetime(2023, 10, 2, 13, 43, 36), datetime.datetime(2023, 10, 4, 1, 54, 39), datetime.datetime(2023, 10, 20, 15, 20, 11), datetime.datetime(2023, 11, 7, 8, 6, 31), datetime.datetime(2023, 12, 8, 18, 26, 10), datetime.datetime(2023, 12, 13, 11, 49, 59), datetime.datetime(2023, 12, 20, 14, 43, 8), datetime.datetime(2024, 1, 19, 11, 42, 13), datetime.datetime(2024, 3, 1, 18, 26, 55), datetime.datetime(2024, 3, 7, 4, 8, 44), datetime.datetime(2024, 3, 21, 12, 42, 45), datetime.datetime(2024, 3, 27, 2, 34, 26), datetime.datetime(2024, 4, 5, 21, 54, 33), datetime.datetime(2024, 4, 16, 7, 37, 46)]
# Crate date range: from 2020-01-13 08:17:51 to 2024-04-16 07:37:46
# [datetime.datetime(2020, 3, 6, 6, 58, 33), datetime.datetime(2020, 5, 26, 8, 23, 18), datetime.datetime(2020, 6, 12, 3, 12, 33), datetime.datetime(2020, 7, 20, 10, 18, 11), datetime.datetime(2020, 7, 30, 9, 13, 48), datetime.datetime(2020, 8, 25, 3, 51, 39), datetime.datetime(2021, 8, 10, 5, 57, 23), datetime.datetime(2021, 9, 16, 23, 46, 38), datetime.datetime(2021, 10, 1, 10, 34, 11), datetime.datetime(2021, 12, 20, 20, 1, 27), datetime.datetime(2022, 4, 7, 19, 34, 16), datetime.datetime(2022, 4, 25, 11, 37, 59), datetime.datetime(2022, 5, 26, 4, 5, 7), datetime.datetime(2022, 6, 17, 3, 8, 39), datetime.datetime(2022, 7, 28, 6, 44, 1), datetime.datetime(2022, 8, 3, 6, 0, 36), datetime.datetime(2022, 8, 4, 5, 43, 41), datetime.datetime(2022, 10, 1, 3, 17, 7), datetime.datetime(2022, 11, 7, 13, 49, 26), datetime.datetime(2023, 2, 28, 10, 50, 45), datetime.datetime(2023, 3, 14, 3, 39, 22), datetime.datetime(2023, 3, 15, 22, 10, 50), datetime.datetime(2023, 3, 21, 5, 59, 1), datetime.datetime(2023, 4, 19, 7, 40, 52), datetime.datetime(2023, 5, 9, 12, 40, 18), datetime.datetime(2023, 7, 6, 3, 38, 49), datetime.datetime(2023, 8, 1, 3, 4, 32), datetime.datetime(2023, 8, 17, 11, 17, 16), datetime.datetime(2023, 8, 17, 15, 14, 59), datetime.datetime(2023, 9, 8, 1, 51, 57), datetime.datetime(2023, 9, 17, 9, 47, 20), datetime.datetime(2023, 9, 25, 9, 54, 55), datetime.datetime(2023, 9, 27, 10, 5, 32), datetime.datetime(2023, 9, 30, 8, 35, 52), datetime.datetime(2023, 10, 9, 20, 42, 59), datetime.datetime(2023, 10, 23, 8, 44, 49), datetime.datetime(2023, 11, 6, 7, 45, 27), datetime.datetime(2023, 11, 16, 8, 29, 32), datetime.datetime(2023, 12, 14, 0, 53, 42), datetime.datetime(2024, 1, 3, 15, 14, 33), datetime.datetime(2024, 1, 15, 1, 33, 9), datetime.datetime(2024, 1, 19, 3, 57, 57), datetime.datetime(2024, 2, 5, 7, 52, 27), datetime.datetime(2024, 2, 20, 16, 37, 59), datetime.datetime(2024, 3, 18, 12, 24, 55), datetime.datetime(2024, 3, 27, 13, 46, 8), datetime.datetime(2024, 4, 12, 9, 31, 55), datetime.datetime(2024, 4, 16, 9, 25, 51), datetime.datetime(2024, 4, 22, 11, 11, 36), datetime.datetime(2024, 4, 23, 7, 43, 9)]
# Closed date range: from 2020-03-06 06:58:33 to 2024-04-23 07:43:09

# %% [markdown]
# ## Prompts

# %%
EXPERIMENT_RESULTS_PATH = "../AutonomicTester/experiment_results"
VALIDATION_SET_PATH = "../FineTuneDataset/validation_paths_v4_q3diff5p.json"
GPT_RESULTS_PATH = os.path.join(EXPERIMENT_RESULTS_PATH, "GPT3.5Turbo")
LLAMA3_RESULTS_PATH = os.path.join(EXPERIMENT_RESULTS_PATH, "Llama3 70B")

# %%
def read_validation_set():
    with open(VALIDATION_SET_PATH) as f:
        validation_set = json.load(f)
        validation_set = [os.path.basename(path) for path in validation_set]
    pattern = r"prompt_(buggy|fixed|similar)_(\d+)_([-A-Za-z]+)_v\d+.txt"
    validation_list = []
    for name in validation_set:
        match = re.search(pattern, name)
        scenario = match.group(1)
        bug_id = int(match.group(2))
        project = match.group(3)
        validation_list.append(
            {"scenario": scenario, "bug_id": bug_id, "project": project}
        )
    df_validation = pd.DataFrame(validation_list).sort_values(
        by=["project", "bug_id", "scenario"]
    )
    return df_validation

# %%
def read_llm_prompt_set(llm_results_path):
    llm_stats = []
    for exp in os.listdir(llm_results_path):
        scenario = exp.split("_")[-1]
        stats_path = os.path.join(llm_results_path, exp, "statistics.csv")
        if not os.path.exists(stats_path):
            continue
        df_stats = pd.read_csv(stats_path)
        df_stats["scenario"] = scenario
        llm_stats.append(df_stats)
    df_llm_stats = pd.concat(llm_stats).drop(columns="elapsed_nanoseconds")
    return df_llm_stats

# %%
df_validation_prompt_set = read_validation_set()
df_llama3_prompt_set = read_llm_prompt_set(LLAMA3_RESULTS_PATH)
df_gpt3_prompt_set = read_llm_prompt_set(GPT_RESULTS_PATH)
df_prompt_set = df_llama3_prompt_set.join(
    df_validation_prompt_set.set_index(["project", "bug_id", "scenario"]),
    how="inner",
    on=["project_id", "bug_id", "scenario"],
)
df_prompt_stats = df_prompt_set.join(
    df_gpt3_prompt_set.set_index(["project_id", "bug_id", "scenario"]),
    how="inner",
    on=["project_id", "bug_id", "scenario"],
    lsuffix="_llama3",
    rsuffix="_gpt",
)

# %%
df_prompt_stats["#characters_gpt"].equals(df_prompt_stats["#characters_llama3"])
# Out:
# True

# %%
df_prompt_stats
# Out:
#           project_id  bug_id  #characters_llama3  #tokens_llama3 scenario  \
# 0        spring-boot       7                3646             976    buggy
# 1        spring-boot      18                5451            1201    buggy
# 2     shardingsphere      10                3635             952    buggy
# 3        spring-boot       3               11641            2959    buggy
# 4        spring-boot      16                5394            1386    buggy
# ..               ...     ...                 ...             ...      ...
# 45       spring-boot      18                5515            1216  similar
# 46        micrometer       4                6947            1992  similar
# 47  dolphinscheduler      11                3535             943  similar
# 48  dolphinscheduler       2                4369            1203  similar
# 49       spring-boot       1                2600             767  similar
#
#     #characters_gpt  #tokens_gpt
# 0              3646          932
# 1              5451         1202
# 2              3635          954
# 3             11641         2961
# 4              5394         1387
# ..              ...          ...
# 45             5515         1218
# 46             6947         1994
# 47             3535          945
# 48             4369         1204
# 49             2600          768
#
# [1897 rows x 7 columns]

# %%
df_defectsat_prompt_set = df_llama3_prompt_set[
    df_llama3_prompt_set["project_id"].isin(
        ["spring-boot", "shardingsphere", "dolphinscheduler", "micrometer"]
    )
]
print("Total prompts:", len(df_llama3_prompt_set))
num_all_bugs = len(df_llama3_prompt_set[df_llama3_prompt_set["scenario"] == "buggy"])
num_all_fixes = len(df_llama3_prompt_set[df_llama3_prompt_set["scenario"] == "fixed"])
num_all_similar = len(
    df_llama3_prompt_set[df_llama3_prompt_set["scenario"] == "similar"]
)
print("#all bugs:", num_all_bugs)
print("#all fixed:", num_all_fixes)
print("#all similar:", num_all_similar)
print("#Defects4J prompts:", len(df_llama3_prompt_set) - len(df_defectsat_prompt_set))
df_defectsat_prompt_set["scenario"].value_counts()
# Out:
# Total prompts: 1975
# #all bugs: 719
# #all fixed: 719
# #all similar: 537
# #Defects4J prompts: 1825
# scenario
# buggy      50
# fixed      50
# similar    50
# Name: count, dtype: int64

# %%
df_prompt_stats[
    df_prompt_stats["project_id"].isin(
        ["spring-boot", "shardingsphere", "dolphinscheduler", "micrometer"]
    )
]["scenario"].value_counts()
# Out:
# scenario
# buggy      48
# fixed      48
# similar    48
# Name: count, dtype: int64

# %%
df_prompt_stats["scenario"].value_counts()
# Out:
# scenario
# buggy      693
# fixed      693
# similar    511
# Name: count, dtype: int64

# %%
df_prompt_stats["#characters_gpt"].describe()
# Out:
# count     1897.000000
# mean      7777.778071
# std       3704.321572
# min        931.000000
# 25%       5205.000000
# 50%       6604.000000
# 75%       9563.000000
# max      26552.000000
# Name: #characters_gpt, dtype: float64

# %%
df_prompt_stats["#tokens_llama3"].describe()
# Out:
# count    1897.000000
# mean     2406.736953
# std      1264.445760
# min       252.000000
# 25%      1506.000000
# 50%      2046.000000
# 75%      2929.000000
# max      8136.000000
# Name: #tokens_llama3, dtype: float64

# %%
df_prompt_stats["#tokens_gpt"].describe()
# Out:
# count    1897.000000
# mean     2408.142857
# std      1264.380421
# min       253.000000
# 25%      1508.000000
# 50%      2051.000000
# 75%      2930.000000
# max      8137.000000
# Name: #tokens_gpt, dtype: float64

# %%
df_prompt_stats[["project_id", "bug_id", "scenario"]].to_csv(
    "filtered_prompts.csv", index=False
)

# %%
summarize_prompts_stats(GPT_RESULTS_PATH)
# Out:
# Found 50 prompts for fixed scenarios
# Found 50 prompts for similar scenarios
# Found 50 prompts for buggy scenarios
# Found 681 prompts for buggy scenarios
# Found 681 prompts for fixed scenarios
# Found 497 prompts for similar scenarios
# #Characters
# min: 931, max: 52754, average: 8197
# #Tokens
# min: 253, max: 14591, average: 2561

# %%
summarize_prompts_stats(LLAMA3_RESULTS_PATH)
# Out:
# Found 50 prompts for buggy scenarios
# Found 669 prompts for buggy scenarios
# Found 487 prompts for similar scenarios
# Found 669 prompts for fixed scenarios
# Found 50 prompts for fixed scenarios
# Found 50 prompts for similar scenarios
# #Characters
# min: 931, max: 26552, average: 7818
# #Tokens
# min: 252, max: 8136, average: 2416
